# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

img1= cv2.imread('greyscale_lenna.jpg')
b1 = img1[:,:,0]
g1 = img1[:,:,1]
r1 = img1[:,:,2]
prop1 = img1.shape
for i in range(prop1[0]): 
    for j in range(prop1[1]): 
        img1[i][j] = ((25.064)/(256.0))*img1[i][j][0] + ((129.057)/(256.0))*img1[i][j][1] + (16+((65.738)/(256.0)))*img1[i][j][2]
        
        
img2= cv2.imread('greyscale_lenna.jpg')
b2 = img2[:,:,0]
g2 = img2[:,:,1]
r2 = img2[:,:,2]
prop2 = img2.shape
for i in range(prop2[0]): 
    for j in range(prop2[1]): 
        img2[i][j] = ((112.439)/(256.0))*img2[i][j][0] + ((-74.494)/(256.0))*img2[i][j][1] + (128+((-37.945)/(256.0)))*img2[i][j][2]
        
        
img3= cv2.imread('greyscale_lenna.jpg')
b3 = img3[:,:,0]
g3 = img3[:,:,1]
r3 = img3[:,:,2]
prop3 = img3.shape
for i in range(prop3[0]): 
    for j in range(prop3[1]): 
        img3[i][j] = ((-18.285)/(256.0))*img3[i][j][0] + ((-94.154)/(256.0))*img3[i][j][1] + (128+((112.439)/(256.0)))*img3[i][j][2]
        
        
YCbCr = np.vstack([img1, img2, img3]) 
cv2.imwrite('y.jpg',YCbCr)  
plt.imshow(YCbCr)
